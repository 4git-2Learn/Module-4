# %% [markdown]
# Exercise 1: Make an empty list and call it names

# %%
# list
days_of_the_week = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
print(days_of_the_week)
# Out:
# ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# %% [markdown]
# Exercise 2: Make names filled with names of 5 people: Hannah, Victor, Sam, James, Sarah

# %%
# list
names_of_five_pple = ["Hannah", "Victor", "Sam", "James", "Sarah"]
print(names_of_five_pple)
# Out:
# ['Hannah', 'Victor', 'Sam', 'James', 'Sarah']

# %% [markdown]
# Exercise 3: Make names sort in reverse. Print out the list using a for-loop

# %%
# Sort name list in reverse
x = ""
names_list = ['Hannah', 'Victor', 'Sam', 'James', 'Sarah']
for x in names_list:
    names_list.sort(reverse=True)
    print(names_list)
# Out:
# ['Victor', 'Sarah', 'Sam', 'James', 'Hannah']
# ['Victor', 'Sarah', 'Sam', 'James', 'Hannah']
# ['Victor', 'Sarah', 'Sam', 'James', 'Hannah']
# ['Victor', 'Sarah', 'Sam', 'James', 'Hannah']
# ['Victor', 'Sarah', 'Sam', 'James', 'Hannah']

# %% [markdown]
# Exercise 4: Make names sorted alphabetically. Print out the list using while loop

# %%
#sort names alphabetically
names_list = ["Hannah", "Victor", "Sam", "James", "Sarah"]
names_list.sort()
print(names_list)
# Out:
# ['Hannah', 'James', 'Sam', 'Sarah', 'Victor']

# %% [markdown]
# Exercise 5: Pull out the fourth item from names and print it out

# %%
#pull out the first item from names list and print 
names_list = ["Hannah", "Victor", "Sam", "James", "Sarah"]
names_pulled = names_list[3]
print(names_pulled)
# Out:
# James

# %% [markdown]
# Exercise 6: Pull out the first item from names and print it out

# %%
#pull out the first item from names list and print 
names_list = ["Hannah", "Victor", "Sam", "James", "Sarah"]
names_pulled = names_list[0]
print(names_pulled)
# Out:
# Hannah

# %% [markdown]
# Exercise 7: Make a variable named fruits that contains a string "Apples, Oranges, Bananas, Pineapples, Persimmons, Dragonfruit" and make it into a list splitting it by the commas.

# %%
#make a list of fruits 
fruit_list = ["Apples, Oranges, Bananas, Pineapples, Persimmons, Dragonfruit"]
print(fruit_list)
# Out:
# ['Apples, Oranges, Bananas, Pineapples, Persimmons, Dragonfruit']

# %% [markdown]
# Exercise 8: Create a list of the first 10 square numbers. i.e. the square of each integer from 1 to 10.

# %%
import math
import random as rand
def sqrt_root(x, y):
    x = rand.randint(1, 11)
    math.sqrt(x)          
    print("The square root of 1 is: ", math.sqrt(1))
    print("The square root of 2 is: ", math.sqrt(2))
    print("The square root of 3 is: ", math.sqrt(3))
    print("The square root of 4 is: ", math.sqrt(4))
    print("The square root of 5 is: ", math.sqrt(5))
    print("The square root of 6 is: ", math.sqrt(6))
    print("The square root of 7 is: ", math.sqrt(7))
    print("The square root of 8 is: ", math.sqrt(8))
    print("The square root of 9 is: ", math.sqrt(9))
    print("The square root of 10 is: ", math.sqrt(10))
    return
 
    
sqrt_root(1, 11)
# Out:
# The square root of 1 is:  1.0
# The square root of 2 is:  1.4142135623730951
# The square root of 3 is:  1.7320508075688772
# The square root of 4 is:  2.0
# The square root of 5 is:  2.23606797749979
# The square root of 6 is:  2.449489742783178
# The square root of 7 is:  2.6457513110645907
# The square root of 8 is:  2.8284271247461903
# The square root of 9 is:  3.0
# The square root of 10 is:  3.1622776601683795

# %% [markdown]
# Exercise 9: Create a multiplication table from 1 to 10

# %%
def multiply_table(start, end) :
    num = int(input("Enter a number: "))
    print(num,"*",1,"=",num * 1) 
    print(num,"*",2,"=",num * 2)
    print(num,"*",3,"=",num * 3)
    print(num,"*",4,"=",num * 4)
    print(num,"*",5,"=",num * 5)
    print(num,"*",6,"=",num * 6)
    print(num,"*",7,"=",num * 7)
    print(num,"*",8,"=",num * 8)
    print(num,"*",9,"=",num * 9)
    print(num,"*",9,"=",num * 10)
    return

multiply_table(1, 10)
# Out:
# Enter a number: 3
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 9 = 30

# %% [markdown]
# Exercise 10: Write a program that gets test scores from a user and then calculates and displays the average of the scores that have been enter. The output of the program should show the original scores and the average.

# %% [markdown]
# Challenge:
# Write a program that maintains a list of movies, and the user can list all the movies, add a movie to the list, or delete a movie from the list.
#
# Example
#
# ###### COMMAND MENU
# ```
# list - list all movies
# add - add a movie
# del - delete a movie
# exit - exit program
# ```
#
# ###### Command: list
# ```
#  1. Toy Story
#  2. Lion King
#  3. Frozen
#  ```
#
# ###### Command: add
#  ```
#  Name: Snow White
#  Snow White was added.
#  ```
#
# ###### Command: del
# ```
#  Number: 3
#  Frozen was deleted.```

# %%
#List of movies 
all_movies_list = ["Toy Story", "Lion King", "Frozen"]
all_movies_list.append("Snow White")
print(all_movies_list)
# Out:
# ['Toy Story', 'Lion King', 'Frozen', 'Snow White']

# %%
#add a movie to the list 
all_movies_list = ["Toy Story", "Lion King", "Frozen"]
all_movies_list.remove("Frozen")
print("Number: 3: ", "\n", "Frozen was deleted. ----")
# Out:
# Number: 3:
#  Frozen was deleted. ----
